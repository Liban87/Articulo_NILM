# %%
import numpy as np
import pandas as pd
#import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# from pandas.plotting import scatter_matrix
#import seaborn as sns
#import matplotlib as mpl
#from matplotlib import cm
import os
import sys
import datetime
from datetime import timedelta
import random

warnings.filterwarnings("ignore")
from sklearn.preprocessing import StandardScaler
# from sklearn.impute import SimpleImputer 
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score, cross_val_predict
from sklearn.pipeline import Pipeline
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report,f1_score, recall_score
from scipy.stats import uniform, randint

from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
import xgboost as xgb
import joblib #https://joblib.readthedocs.io/en/latest/
from imblearn.under_sampling import TomekLinks
from sklearn.neighbors import NearestNeighbors

# Generate and plot a synthetic imbalanced classification dataset
from collections import Counter
from imblearn.under_sampling import EditedNearestNeighbours

path = './'
# path = '/content/drive/MyDrive/Colab Notebooks/Industria_4/Analitica_Datos/'
name = 'household_power_consumption.csv'

# %% [markdown]
# ## Dataset loading and preprocessing
# 1. During data loading the dates and times are parsed on an unique column using parse_dates parameter on read_csv function, the ? data is replaced with nan.
#
# 2. nan values are replaced by the corresponding column median.
#
# 3. 2 new features are created from the previous ones, the global apparent power and power factor.
#
# 4. Asign cathegorical tag tothe samples of the dataset. this is necessary beacuse subsequent steps involve the training of clasification models that identifies the kind of energy consumption corresponding to a global electrical measurements sample. Namely:
#     * no consumption on any zone (___tag 0___)
#     * zone 2 has the main consumption (___tag 1___)
#     * zone 3 has the main consumption (___tag 2___)
#     * the two zones has the same consumption (___tag 3___)
#
#     zone 2 Corresponds to the Laundry room, containing washing machine, tumble dryer a refrigerator and a light.
#
#     zone 3 corresponds to an electric water heater and an air conditioner.
#
# Notes:
# - [X] ___could be interesting to have a range when zones are considered equal___
# - [X] ___Cero consumption entries can be droped, because there's no need to classify them.
# - [ ] ___Could be necessary to create more classes in order to add relevance to the classification task___

# %%
def load_preprocess_data():
    '''
    Read the csv file with ';' separator beetwen columns, parsing dates 
    and asigning consumption category tags to each sample, returns global 
    electrical varibles as X and cathegories as Y
    '''
    #Takes the columns 'Date' and 'Time' from the original csv and combines it on a single 'Date' Column 
    df = pd.read_csv(path+name, sep = ';',
                parse_dates={'TimeStamp':['Date','Time']},
                infer_datetime_format=True,
                low_memory=False, na_values=['nan','?']
                )

    df.sort_values(by='TimeStamp')
    
    #Data imputation replacing nan fields with the column median
    for i in df.columns[1:]:
        median = df[i].median() # option 3
        df[i].fillna(median, inplace=True)
    
    #select just the columns needed
    df3 = df.loc[:int(len(df)), ['Global_active_power', 'Global_reactive_power', 
                               'Voltage',	'Global_intensity',	'Sub_metering_2',
                               'Sub_metering_3']]
    
    df3['Global_apparent_power'] = (df3['Global_active_power']**2+df3['Global_reactive_power']**2)**(1/2)
    
    df3['Power_factor'] = df3['Global_active_power']/df3['Global_apparent_power']
    
    # #assign categorical tags to the data using the folowing rules, 
     
    # conditions = [
    # (df3['Sub_metering_2'] == 0) & (df3['Sub_metering_3'] == 0), ## Etiqueta 0: No hay consumo
    # df3['Sub_metering_2'] > df3['Sub_metering_3'], ## Etiqueta 1: Mayor consumo Zona 2
    # df3['Sub_metering_2'] < df3['Sub_metering_3'], ## Etiqueta 2: Mayor consumo Zona 3
    # df3['Sub_metering_2'] == df3['Sub_metering_3']] ## Etiqueta 3: Consumo en ambas zonas por igual
    
    #asignación de nuevas etiquetas con rangos mas flexibles
    S2avg = df3['Sub_metering_2'].mean()
    S3avg = df3['Sub_metering_3'].mean()
    S2 = df3['Sub_metering_2']
    S3 = df3['Sub_metering_3']
    conditions = [
        ((S2>0)&(S2<(S3+0.25*S3avg))) | ((S3>0)&(S3<(S2+0.25*S2avg))), #Etiqueta 0:El consumo de ambas zonas es similar
        S2 > (S3+0.25*S3avg), #Etiqueta 0: consumo en zona 1 considerablemente mayor a zona 3
        S3 > (S2+0.25*S2avg), #Etiqueta 1: consumo en zona 2 considerablemente mayor a zona 2
        (S2 == 0) & (S3==0) #Etiqueta 3 el consumo es despreciable
    ]
    
    choices = [0, 1, 2, 3]
    y = np.select(conditions, choices, default=4)
    df3.drop(columns=['Sub_metering_2',	'Sub_metering_3'], inplace=True)
    df3['label'] = y
    dff = df3.drop(df3[df3['label'] == 3].index)
    y = y[y != 3]

    counter = Counter(y)
    print('Distribución de las clases:', counter)
    print('xdata shape: ',dff.shape)
    print(y.size)
    Xdata =dff.drop(columns=['label'])
    #Xdata = dff.loc[:int(len(dff)), ['Global_active_power', 'Global_reactive_power', 
    #                            'Voltage','Global_intensity','Global_apparent_power','Power_factor']]

    return Xdata, y

# %%
#Here is executed the data loading, and pre-processing.
Xdata, y = load_preprocess_data()
print(Xdata.shape)
Xdata.head(10)
# Out:
# Distribución de las clases: Counter({2: 842705, 0: 528501, 1: 83949})
# xdata shape:  (1455155, 7)
# 1455155
# (1455155, 6)
#    Global_active_power  Global_reactive_power  Voltage  Global_intensity  \
# 0                4.216                  0.418   234.84              18.4
# 1                5.360                  0.436   233.63              23.0
# 2                5.374                  0.498   233.29              23.0
# 3                5.388                  0.502   233.74              23.0
# 4                3.666                  0.528   235.68              15.8
# 5                3.520                  0.522   235.02              15.0
# 6                3.702                  0.520   235.09              15.8
# 7                3.700                  0.520   235.22              15.8
# 8                3.668                  0.510   233.99              15.8
# 9                3.662                  0.510   233.86              15.8
#
#    Global_apparent_power  Power_factor
# 0               4.236671      0.995121
# 1               5.377704      0.996708
# 2               5.397025      0.995734
# 3               5.411335      0.995688
# 4               3.703828      0.989787
# 5               3.558495      0.989182
# 6               3.738342      0.990278
# 7               3.736362      0.990268
# 8               3.703286      0.990472
# 9               3.697343      0.990441

# %% [markdown]
# ## Split and Balance the Dataset
# Due to the considerable high diferences in the quantity of samples for the various categories, it is necessary to make the training subset more balanced by means of undersampling the mayority classes. This is achieved using two undersampling steps first with EditedNearestNeighbours and then with TomekLinks.
#
# Notes:
# * ___Is needed to check performance using another undersampling or oversampling methods such as ADASYN or random___

# %%
def split_balance_data(Xdata, y):
    # Tamaño Xtrain 70%, Tamaño Xtest 15%, Xprod 15%
    Xtrain, Xtest, ytrain, ytest = train_test_split(Xdata, y, test_size=0.3, random_state=2)
    Xprod, Xtest, yprod, ytest = train_test_split(Xtest, ytest, test_size=0.5, random_state=2)
    Xtest1 = Xtest.copy()
    print('-Train (70%):', Xtrain.shape, '\n-Test (15%):', Xtest.shape, '\n-Production (15%):', Xprod.shape)
    
    # summarize class distribution
    counter = Counter(ytrain)
    print('Sin balancear las clases:', counter)

    # configure the undersampling
    undersample = EditedNearestNeighbours(n_neighbors=7, sampling_strategy = 'not minority', kind_sel='all')
    # transform the dataset
    X1, y1 = undersample.fit_resample(Xtrain, ytrain)
    # summarize the new class distribution
    counter = Counter(y1)
    print('Balanceo con Edited:', counter)

    # define the undersampling method
    under = TomekLinks()
    X2, y2 = under.fit_resample(X1, y1)
    # summarize the new class distribution
    counter = Counter(y2)
    print('Balanceo con TomeLinks:', counter)
    return X2, Xtest, Xprod, y2, ytest, yprod

# %%
X2, Xtest, Xprod, y2, ytest, yprod = split_balance_data(Xdata, y)
# Out:
# -Train (70%): (1018608, 6)
# -Test (15%): (218274, 6)
# -Production (15%): (218273, 6)
# Sin balancear las clases: Counter({2: 590003, 0: 369724, 1: 58881})
# Balanceo con Edited: Counter({2: 170887, 1: 58881, 0: 20879})
# Balanceo con TomeLinks: Counter({2: 170232, 1: 57745, 0: 20879})

# %%
X2.head(10)
# Out:
#    Global_active_power  Global_reactive_power  Voltage  Global_intensity  \
# 0                1.580                  0.324   239.67               6.6
# 1                0.312                  0.250   241.17               1.6
# 2                0.288                  0.202   240.84               1.4
# 3                0.194                  0.116   240.73               1.0
# 4                2.998                  0.174   235.52              12.6
# 5                1.460                  0.336   238.65               6.2
# 6                0.742                  0.202   241.00               3.2
# 7                1.546                  0.332   239.11               6.6
# 8                0.316                  0.174   239.28               1.6
# 9                0.452                  0.364   241.33               2.4
#
#    Global_apparent_power  Power_factor
# 0               1.612878      0.979615
# 1               0.399805      0.780381
# 2               0.351778      0.818697
# 3               0.226035      0.858273
# 4               3.003045      0.998320
# 5               1.498164      0.974526
# 6               0.769005      0.964884
# 7               1.581246      0.977710
# 8               0.360738      0.875982
# 9               0.580345      0.778847

# %%
from sklearn.utils import class_weight

# Obtener los pesos de clase inversamente proporcionales a la frecuencia de clases
# class_weights = class_weight.compute_class_weight(class_weight='balanced', classes=np.unique(y2), y=y2)
# , class_weight=dict(enumerate(class_weights))

## Pipeline
steps=[   
       [('std', StandardScaler()),
        # ('rep',  PCA()),
        ('cla', xgb.XGBClassifier(random_state=42))], # objective="multi:softprob", , eval_metric="auc"
      ]

# parameters = [{
#             #  'rep__n_components' : [0.99],
#              "cla__colsample_bytree": [0.3],
#               # "cla__gamma": [0.5],
#               "cla__learning_rate": [0.1], # default 0.1 
#               "cla__max_depth": [5], # default 3
#               "cla__n_estimators": [200], # default 100
#               "cla__subsample": [0.2],
#               "cla__scale_pos_weight": [3.8],
#               "cla__min_child_weight": [10],
#              }
#              ]

parameters = [
              {
              #"rep__n_components" : [0.99],
              "cla__colsample_bytree": [0.3, 0.4, 0.6, 0.7],
              "cla__gamma": [0, 0.5],
              "cla__learning_rate": [0.03, 0.05, 0.1, 0.2, 0.3 ], # default 0.1 
              "cla__max_depth": [2, 3, 4, 5], # default 3
              "cla__n_estimators": [10, 30, 100, 200], # default 100
              "cla__subsample": [0.4, 0.5, 0.6],
              "cla__min_child_weight": [10]
             }
             ]

#label_models = ['PCA_RandomForest_p3_','PCA_KNN_p3_', 'PCA_SVC_p3_']
label_models = ['XGB']

best_model = []
best_params = []
best_score = []

filename = path+'Results/Model_p3_other2'

for i in range(len(steps)):
    print('modelo %d/%d' % (i+1,len(steps)))
    grid_search = GridSearchCV(Pipeline(steps[i]), parameters[i], n_jobs=-1, cv=3,
                                scoring='balanced_accuracy', verbose=2)
    grid_search.fit(X2, y2)
    #print(grid_search.cv_results_)
    #mejor modelo entrenado
    best_model += [grid_search.best_estimator_]
    best_params += [grid_search.best_params_]
    best_score += [grid_search.best_score_]
    joblib.dump(best_model,filename+".pkl")
# Out:
# modelo 1/1
# Fitting 3 folds for each of 1920 candidates, totalling 5760 fits
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=2, cla__min_child_weight=10, cla__n_estimators=10, cla__subsample=0.4; total time=   0.7s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=2, cla__min_child_weight=10, cla__n_estimators=10, cla__subsample=0.6; total time=   0.7s[CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=2, cla__min_child_weight=10, cla__n_estimators=10, cla__subsample=0.5; total time=   0.6s
#
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=2, cla__min_child_weight=10, cla__n_estimators=10, cla__subsample=0.5; total time=   0.7s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=2, cla__min_child_weight=10, cla__n_estimators=10, cla__subsample=0.4; total time=   0.7s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=2, cla__min_child_weight=10, cla__n_estimators=10, cla__subsample=0.6; total time=   0.7s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=2, cla__min_child_weight=10, cla__n_estimators=10, cla__subsample=0.6; total time=   0.6s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=2, cla__min_child_weight=10, cla__n_estimators=10, cla__subsample=0.4; total time=   0.8s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=2, cla__min_child_weight=10, cla__n_estimators=10, cla__subsample=0.5; total time=   0.8s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=2, cla__min_child_weight=10, cla__n_estimators=30, cla__subsample=0.4; total time=   1.4s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=2, cla__min_child_weight=10, cla__n_estimators=30, cla__subsample=0.5; total time=   1.4s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=2, cla__min_child_weight=10, cla__n_estimators=30, cla__subsample=0.6; total time=   1.4s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=2, cla__min_child_weight=10, cla__n_estimators=30, cla__subsample=0.5; total time=   1.4s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=2, cla__min_child_weight=10, cla__n_estimators=30, cla__subsample=0.4; total time=   1.5s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=2, cla__min_child_weight=10, cla__n_estimators=30, cla__subsample=0.5; total time=   1.4s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=2, cla__min_child_weight=10, cla__n_estimators=30, cla__subsample=0.4; total time=   1.6s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=2, cla__min_child_weight=10, cla__n_estimators=30, cla__subsample=0.6; total time=   1.5s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=2, cla__min_child_weight=10, cla__n_estimators=30, cla__subsample=0.6; total time=   1.5s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=2, cla__min_child_weight=10, cla__n_estimators=100, cla__subsample=0.4; total time=   4.5s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=2, cla__min_child_weight=10, cla__n_estimators=100, cla__subsample=0.4; total time=   4.5s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=2, cla__min_child_weight=10, cla__n_estimators=100, cla__subsample=0.5; total time=   4.5s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=2, cla__min_child_weight=10, cla__n_estimators=100, cla__subsample=0.4; total time=   4.6s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=2, cla__min_child_weight=10, cla__n_estimators=100, cla__subsample=0.5; total time=   4.7s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=2, cla__min_child_weight=10, cla__n_estimators=100, cla__subsample=0.5; total time=   4.8s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=2, cla__min_child_weight=10, cla__n_estimators=100, cla__subsample=0.6; total time=   4.8s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=2, cla__min_child_weight=10, cla__n_estimators=100, cla__subsample=0.6; total time=   4.4s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=3, cla__min_child_weight=10, cla__n_estimators=10, cla__subsample=0.4; total time=   0.7s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=3, cla__min_child_weight=10, cla__n_estimators=10, cla__subsample=0.4; total time=   0.7s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=3, cla__min_child_weight=10, cla__n_estimators=10, cla__subsample=0.4; total time=   0.8s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=2, cla__min_child_weight=10, cla__n_estimators=100, cla__subsample=0.6; total time=   4.7s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=3, cla__min_child_weight=10, cla__n_estimators=10, cla__subsample=0.5; total time=   0.7s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=3, cla__min_child_weight=10, cla__n_estimators=10, cla__subsample=0.5; total time=   0.7s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=3, cla__min_child_weight=10, cla__n_estimators=10, cla__subsample=0.5; total time=   0.7s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=3, cla__min_child_weight=10, cla__n_estimators=10, cla__subsample=0.6; total time=   0.8s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=3, cla__min_child_weight=10, cla__n_estimators=10, cla__subsample=0.6; total time=   0.7s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=3, cla__min_child_weight=10, cla__n_estimators=10, cla__subsample=0.6; total time=   0.8s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=3, cla__min_child_weight=10, cla__n_estimators=30, cla__subsample=0.4; total time=   1.8s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=3, cla__min_child_weight=10, cla__n_estimators=30, cla__subsample=0.4; total time=   1.8s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=3, cla__min_child_weight=10, cla__n_estimators=30, cla__subsample=0.4; total time=   2.2s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=3, cla__min_child_weight=10, cla__n_estimators=30, cla__subsample=0.5; total time=   1.9s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=3, cla__min_child_weight=10, cla__n_estimators=30, cla__subsample=0.5; total time=   1.9s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=3, cla__min_child_weight=10, cla__n_estimators=30, cla__subsample=0.5; total time=   1.9s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=3, cla__min_child_weight=10, cla__n_estimators=30, cla__subsample=0.6; total time=   1.9s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=3, cla__min_child_weight=10, cla__n_estimators=30, cla__subsample=0.6; total time=   1.8s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=3, cla__min_child_weight=10, cla__n_estimators=30, cla__subsample=0.6; total time=   1.9s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=2, cla__min_child_weight=10, cla__n_estimators=200, cla__subsample=0.4; total time=   8.8s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=2, cla__min_child_weight=10, cla__n_estimators=200, cla__subsample=0.4; total time=   8.9s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=2, cla__min_child_weight=10, cla__n_estimators=200, cla__subsample=0.5; total time=   9.0s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=2, cla__min_child_weight=10, cla__n_estimators=200, cla__subsample=0.5; total time=   9.2s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=2, cla__min_child_weight=10, cla__n_estimators=200, cla__subsample=0.4; total time=   9.5s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=2, cla__min_child_weight=10, cla__n_estimators=200, cla__subsample=0.5; total time=   9.1s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=2, cla__min_child_weight=10, cla__n_estimators=200, cla__subsample=0.6; total time=   9.8s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=3, cla__min_child_weight=10, cla__n_estimators=100, cla__subsample=0.4; total time=   5.6s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=2, cla__min_child_weight=10, cla__n_estimators=200, cla__subsample=0.6; total time=   8.9s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=3, cla__min_child_weight=10, cla__n_estimators=100, cla__subsample=0.4; total time=   5.4s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=3, cla__min_child_weight=10, cla__n_estimators=100, cla__subsample=0.5; total time=   5.4s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=3, cla__min_child_weight=10, cla__n_estimators=100, cla__subsample=0.5; total time=   5.5s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=3, cla__min_child_weight=10, cla__n_estimators=100, cla__subsample=0.4; total time=   5.7s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=2, cla__min_child_weight=10, cla__n_estimators=200, cla__subsample=0.6; total time=   9.5s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=4, cla__min_child_weight=10, cla__n_estimators=10, cla__subsample=0.4; total time=   0.9s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=4, cla__min_child_weight=10, cla__n_estimators=10, cla__subsample=0.4; total time=   0.9s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=3, cla__min_child_weight=10, cla__n_estimators=100, cla__subsample=0.5; total time=   5.5s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=3, cla__min_child_weight=10, cla__n_estimators=100, cla__subsample=0.6; total time=   5.2s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=3, cla__min_child_weight=10, cla__n_estimators=100, cla__subsample=0.6; total time=   5.6s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=4, cla__min_child_weight=10, cla__n_estimators=10, cla__subsample=0.4; total time=   1.0s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=3, cla__min_child_weight=10, cla__n_estimators=100, cla__subsample=0.6; total time=   5.3s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=4, cla__min_child_weight=10, cla__n_estimators=10, cla__subsample=0.5; total time=   0.8s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=4, cla__min_child_weight=10, cla__n_estimators=10, cla__subsample=0.5; total time=   0.8s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=4, cla__min_child_weight=10, cla__n_estimators=10, cla__subsample=0.5; total time=   0.8s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=4, cla__min_child_weight=10, cla__n_estimators=10, cla__subsample=0.6; total time=   0.9s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=4, cla__min_child_weight=10, cla__n_estimators=10, cla__subsample=0.6; total time=   1.0s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=4, cla__min_child_weight=10, cla__n_estimators=10, cla__subsample=0.6; total time=   0.9s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=4, cla__min_child_weight=10, cla__n_estimators=30, cla__subsample=0.4; total time=   2.1s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=4, cla__min_child_weight=10, cla__n_estimators=30, cla__subsample=0.4; total time=   2.3s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=4, cla__min_child_weight=10, cla__n_estimators=30, cla__subsample=0.5; total time=   2.1s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=4, cla__min_child_weight=10, cla__n_estimators=30, cla__subsample=0.4; total time=   2.5s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=4, cla__min_child_weight=10, cla__n_estimators=30, cla__subsample=0.5; total time=   2.2s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=4, cla__min_child_weight=10, cla__n_estimators=30, cla__subsample=0.6; total time=   2.3s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=4, cla__min_child_weight=10, cla__n_estimators=30, cla__subsample=0.5; total time=   2.4s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=4, cla__min_child_weight=10, cla__n_estimators=30, cla__subsample=0.6; total time=   2.4s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=4, cla__min_child_weight=10, cla__n_estimators=30, cla__subsample=0.6; total time=   2.2s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=3, cla__min_child_weight=10, cla__n_estimators=200, cla__subsample=0.5; total time=  10.3s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=3, cla__min_child_weight=10, cla__n_estimators=200, cla__subsample=0.4; total time=  11.0s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=3, cla__min_child_weight=10, cla__n_estimators=200, cla__subsample=0.4; total time=  11.5s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=3, cla__min_child_weight=10, cla__n_estimators=200, cla__subsample=0.4; total time=  11.3s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=3, cla__min_child_weight=10, cla__n_estimators=200, cla__subsample=0.5; total time=  10.8s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=3, cla__min_child_weight=10, cla__n_estimators=200, cla__subsample=0.6; total time=  10.4s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=4, cla__min_child_weight=10, cla__n_estimators=100, cla__subsample=0.4; total time=   6.6s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=3, cla__min_child_weight=10, cla__n_estimators=200, cla__subsample=0.5; total time=  11.2s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=4, cla__min_child_weight=10, cla__n_estimators=100, cla__subsample=0.4; total time=   6.7s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=3, cla__min_child_weight=10, cla__n_estimators=200, cla__subsample=0.6; total time=  11.1s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=4, cla__min_child_weight=10, cla__n_estimators=100, cla__subsample=0.4; total time=   6.6s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=3, cla__min_child_weight=10, cla__n_estimators=200, cla__subsample=0.6; total time=  11.1s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=4, cla__min_child_weight=10, cla__n_estimators=100, cla__subsample=0.5; total time=   6.4s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=4, cla__min_child_weight=10, cla__n_estimators=100, cla__subsample=0.5; total time=   6.6s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=5, cla__min_child_weight=10, cla__n_estimators=10, cla__subsample=0.4; total time=   1.0s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=4, cla__min_child_weight=10, cla__n_estimators=100, cla__subsample=0.6; total time=   6.2s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=5, cla__min_child_weight=10, cla__n_estimators=10, cla__subsample=0.4; total time=   1.1s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=5, cla__min_child_weight=10, cla__n_estimators=10, cla__subsample=0.4; total time=   1.0s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=4, cla__min_child_weight=10, cla__n_estimators=100, cla__subsample=0.5; total time=   6.4s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=5, cla__min_child_weight=10, cla__n_estimators=10, cla__subsample=0.5; total time=   1.1s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=5, cla__min_child_weight=10, cla__n_estimators=10, cla__subsample=0.6; total time=   1.0s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=5, cla__min_child_weight=10, cla__n_estimators=10, cla__subsample=0.5; total time=   1.1s[CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=5, cla__min_child_weight=10, cla__n_estimators=10, cla__subsample=0.5; total time=   1.1s
#
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=5, cla__min_child_weight=10, cla__n_estimators=10, cla__subsample=0.6; total time=   1.0s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=5, cla__min_child_weight=10, cla__n_estimators=10, cla__subsample=0.6; total time=   1.0s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=4, cla__min_child_weight=10, cla__n_estimators=100, cla__subsample=0.6; total time=   7.2s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=4, cla__min_child_weight=10, cla__n_estimators=100, cla__subsample=0.6; total time=   7.1s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=5, cla__min_child_weight=10, cla__n_estimators=30, cla__subsample=0.4; total time=   2.5s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=5, cla__min_child_weight=10, cla__n_estimators=30, cla__subsample=0.4; total time=   2.5s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=5, cla__min_child_weight=10, cla__n_estimators=30, cla__subsample=0.4; total time=   2.6s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=5, cla__min_child_weight=10, cla__n_estimators=30, cla__subsample=0.5; total time=   2.7s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=5, cla__min_child_weight=10, cla__n_estimators=30, cla__subsample=0.5; total time=   2.8s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=5, cla__min_child_weight=10, cla__n_estimators=30, cla__subsample=0.5; total time=   2.6s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=5, cla__min_child_weight=10, cla__n_estimators=30, cla__subsample=0.6; total time=   2.5s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=5, cla__min_child_weight=10, cla__n_estimators=30, cla__subsample=0.6; total time=   2.5s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=5, cla__min_child_weight=10, cla__n_estimators=30, cla__subsample=0.6; total time=   2.5s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=4, cla__min_child_weight=10, cla__n_estimators=200, cla__subsample=0.4; total time=  12.6s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=4, cla__min_child_weight=10, cla__n_estimators=200, cla__subsample=0.4; total time=  12.9s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=4, cla__min_child_weight=10, cla__n_estimators=200, cla__subsample=0.4; total time=  13.7s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=4, cla__min_child_weight=10, cla__n_estimators=200, cla__subsample=0.5; total time=  12.4s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=4, cla__min_child_weight=10, cla__n_estimators=200, cla__subsample=0.5; total time=  12.6s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=5, cla__min_child_weight=10, cla__n_estimators=100, cla__subsample=0.4; total time=   7.4s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=4, cla__min_child_weight=10, cla__n_estimators=200, cla__subsample=0.6; total time=  12.8s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=4, cla__min_child_weight=10, cla__n_estimators=200, cla__subsample=0.6; total time=  12.9s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=4, cla__min_child_weight=10, cla__n_estimators=200, cla__subsample=0.5; total time=  13.1s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=4, cla__min_child_weight=10, cla__n_estimators=200, cla__subsample=0.6; total time=  13.0s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=5, cla__min_child_weight=10, cla__n_estimators=100, cla__subsample=0.4; total time=   8.1s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=5, cla__min_child_weight=10, cla__n_estimators=100, cla__subsample=0.5; total time=   7.2s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=5, cla__min_child_weight=10, cla__n_estimators=100, cla__subsample=0.5; total time=   7.0s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=5, cla__min_child_weight=10, cla__n_estimators=100, cla__subsample=0.4; total time=   7.5s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=2, cla__min_child_weight=10, cla__n_estimators=10, cla__subsample=0.4; total time=   0.7s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=2, cla__min_child_weight=10, cla__n_estimators=10, cla__subsample=0.4; total time=   0.7s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=2, cla__min_child_weight=10, cla__n_estimators=10, cla__subsample=0.4; total time=   0.7s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=5, cla__min_child_weight=10, cla__n_estimators=100, cla__subsample=0.5; total time=   7.0s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=5, cla__min_child_weight=10, cla__n_estimators=100, cla__subsample=0.6; total time=   7.1s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=2, cla__min_child_weight=10, cla__n_estimators=10, cla__subsample=0.5; total time=   0.6s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=2, cla__min_child_weight=10, cla__n_estimators=10, cla__subsample=0.5; total time=   0.7s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=2, cla__min_child_weight=10, cla__n_estimators=10, cla__subsample=0.5; total time=   0.9s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=2, cla__min_child_weight=10, cla__n_estimators=10, cla__subsample=0.6; total time=   0.7s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=2, cla__min_child_weight=10, cla__n_estimators=10, cla__subsample=0.6; total time=   0.7s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=2, cla__min_child_weight=10, cla__n_estimators=10, cla__subsample=0.6; total time=   0.7s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=5, cla__min_child_weight=10, cla__n_estimators=100, cla__subsample=0.6; total time=   6.9s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=2, cla__min_child_weight=10, cla__n_estimators=30, cla__subsample=0.4; total time=   1.7s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=2, cla__min_child_weight=10, cla__n_estimators=30, cla__subsample=0.4; total time=   1.6s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=2, cla__min_child_weight=10, cla__n_estimators=30, cla__subsample=0.5; total time=   1.7s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=2, cla__min_child_weight=10, cla__n_estimators=30, cla__subsample=0.5; total time=   1.5s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=2, cla__min_child_weight=10, cla__n_estimators=30, cla__subsample=0.4; total time=   1.9s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=5, cla__min_child_weight=10, cla__n_estimators=100, cla__subsample=0.6; total time=   7.5s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=2, cla__min_child_weight=10, cla__n_estimators=30, cla__subsample=0.5; total time=   1.7s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=2, cla__min_child_weight=10, cla__n_estimators=30, cla__subsample=0.6; total time=   1.5s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=2, cla__min_child_weight=10, cla__n_estimators=30, cla__subsample=0.6; total time=   1.6s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=2, cla__min_child_weight=10, cla__n_estimators=30, cla__subsample=0.6; total time=   1.7s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=2, cla__min_child_weight=10, cla__n_estimators=100, cla__subsample=0.4; total time=   4.8s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=2, cla__min_child_weight=10, cla__n_estimators=100, cla__subsample=0.4; total time=   4.9s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=2, cla__min_child_weight=10, cla__n_estimators=100, cla__subsample=0.4; total time=   4.8s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=2, cla__min_child_weight=10, cla__n_estimators=100, cla__subsample=0.5; total time=   4.8s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=2, cla__min_child_weight=10, cla__n_estimators=100, cla__subsample=0.5; total time=   4.9s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=2, cla__min_child_weight=10, cla__n_estimators=100, cla__subsample=0.5; total time=   5.1s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=2, cla__min_child_weight=10, cla__n_estimators=100, cla__subsample=0.6; total time=   4.7s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=5, cla__min_child_weight=10, cla__n_estimators=200, cla__subsample=0.4; total time=  15.2s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=5, cla__min_child_weight=10, cla__n_estimators=200, cla__subsample=0.4; total time=  13.9s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=2, cla__min_child_weight=10, cla__n_estimators=100, cla__subsample=0.6; total time=   4.6s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=2, cla__min_child_weight=10, cla__n_estimators=100, cla__subsample=0.6; total time=   4.6s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=5, cla__min_child_weight=10, cla__n_estimators=200, cla__subsample=0.6; total time=  13.7s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=5, cla__min_child_weight=10, cla__n_estimators=200, cla__subsample=0.4; total time=  15.1s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=5, cla__min_child_weight=10, cla__n_estimators=200, cla__subsample=0.5; total time=  14.0s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=5, cla__min_child_weight=10, cla__n_estimators=200, cla__subsample=0.5; total time=  14.3s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=5, cla__min_child_weight=10, cla__n_estimators=200, cla__subsample=0.5; total time=  14.1s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=5, cla__min_child_weight=10, cla__n_estimators=200, cla__subsample=0.6; total time=  14.1s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=3, cla__min_child_weight=10, cla__n_estimators=10, cla__subsample=0.4; total time=   0.6s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=3, cla__min_child_weight=10, cla__n_estimators=10, cla__subsample=0.4; total time=   0.6s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=3, cla__min_child_weight=10, cla__n_estimators=10, cla__subsample=0.4; total time=   0.6s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.03, cla__max_depth=5, cla__min_child_weight=10, cla__n_estimators=200, cla__subsample=0.6; total time=  14.5s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=3, cla__min_child_weight=10, cla__n_estimators=10, cla__subsample=0.5; total time=   0.7s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=3, cla__min_child_weight=10, cla__n_estimators=10, cla__subsample=0.5; total time=   0.7s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=3, cla__min_child_weight=10, cla__n_estimators=10, cla__subsample=0.5; total time=   0.7s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=3, cla__min_child_weight=10, cla__n_estimators=10, cla__subsample=0.6; total time=   0.8s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=3, cla__min_child_weight=10, cla__n_estimators=10, cla__subsample=0.6; total time=   0.8s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=3, cla__min_child_weight=10, cla__n_estimators=10, cla__subsample=0.6; total time=   0.8s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=3, cla__min_child_weight=10, cla__n_estimators=30, cla__subsample=0.4; total time=   1.7s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=3, cla__min_child_weight=10, cla__n_estimators=30, cla__subsample=0.4; total time=   1.9s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=3, cla__min_child_weight=10, cla__n_estimators=30, cla__subsample=0.4; total time=   2.0s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=3, cla__min_child_weight=10, cla__n_estimators=30, cla__subsample=0.5; total time=   1.7s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=3, cla__min_child_weight=10, cla__n_estimators=30, cla__subsample=0.5; total time=   1.7s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=3, cla__min_child_weight=10, cla__n_estimators=30, cla__subsample=0.6; total time=   1.7s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=3, cla__min_child_weight=10, cla__n_estimators=30, cla__subsample=0.5; total time=   2.1s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=3, cla__min_child_weight=10, cla__n_estimators=30, cla__subsample=0.6; total time=   1.8s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=3, cla__min_child_weight=10, cla__n_estimators=30, cla__subsample=0.6; total time=   1.8s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=2, cla__min_child_weight=10, cla__n_estimators=200, cla__subsample=0.4; total time=   8.9s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=2, cla__min_child_weight=10, cla__n_estimators=200, cla__subsample=0.4; total time=   8.5s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=2, cla__min_child_weight=10, cla__n_estimators=200, cla__subsample=0.4; total time=   9.4s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=2, cla__min_child_weight=10, cla__n_estimators=200, cla__subsample=0.5; total time=   8.8s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=2, cla__min_child_weight=10, cla__n_estimators=200, cla__subsample=0.5; total time=   8.9s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=2, cla__min_child_weight=10, cla__n_estimators=200, cla__subsample=0.5; total time=   9.2s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=3, cla__min_child_weight=10, cla__n_estimators=100, cla__subsample=0.4; total time=   5.2s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=2, cla__min_child_weight=10, cla__n_estimators=200, cla__subsample=0.6; total time=   8.8s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=3, cla__min_child_weight=10, cla__n_estimators=100, cla__subsample=0.4; total time=   5.4s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=3, cla__min_child_weight=10, cla__n_estimators=100, cla__subsample=0.5; total time=   5.4s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=2, cla__min_child_weight=10, cla__n_estimators=200, cla__subsample=0.6; total time=   8.9s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=3, cla__min_child_weight=10, cla__n_estimators=100, cla__subsample=0.4; total time=   5.9s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=2, cla__min_child_weight=10, cla__n_estimators=200, cla__subsample=0.6; total time=   9.2s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=3, cla__min_child_weight=10, cla__n_estimators=100, cla__subsample=0.5; total time=   5.6s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=3, cla__min_child_weight=10, cla__n_estimators=100, cla__subsample=0.5; total time=   5.2s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=4, cla__min_child_weight=10, cla__n_estimators=10, cla__subsample=0.4; total time=   0.9s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=4, cla__min_child_weight=10, cla__n_estimators=10, cla__subsample=0.4; total time=   0.8s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=3, cla__min_child_weight=10, cla__n_estimators=100, cla__subsample=0.6; total time=   5.2s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=4, cla__min_child_weight=10, cla__n_estimators=10, cla__subsample=0.4; total time=   0.9s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=3, cla__min_child_weight=10, cla__n_estimators=100, cla__subsample=0.6; total time=   5.1s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=4, cla__min_child_weight=10, cla__n_estimators=10, cla__subsample=0.5; total time=   0.8s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=4, cla__min_child_weight=10, cla__n_estimators=10, cla__subsample=0.5; total time=   0.9s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=4, cla__min_child_weight=10, cla__n_estimators=10, cla__subsample=0.5; total time=   0.8s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=4, cla__min_child_weight=10, cla__n_estimators=10, cla__subsample=0.6; total time=   0.8s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=4, cla__min_child_weight=10, cla__n_estimators=10, cla__subsample=0.6; total time=   0.9s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=4, cla__min_child_weight=10, cla__n_estimators=10, cla__subsample=0.6; total time=   0.8s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=3, cla__min_child_weight=10, cla__n_estimators=100, cla__subsample=0.6; total time=   6.0s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=4, cla__min_child_weight=10, cla__n_estimators=30, cla__subsample=0.4; total time=   2.1s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=4, cla__min_child_weight=10, cla__n_estimators=30, cla__subsample=0.4; total time=   2.1s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=4, cla__min_child_weight=10, cla__n_estimators=30, cla__subsample=0.5; total time=   2.3s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=4, cla__min_child_weight=10, cla__n_estimators=30, cla__subsample=0.4; total time=   2.3s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=4, cla__min_child_weight=10, cla__n_estimators=30, cla__subsample=0.5; total time=   2.5s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=4, cla__min_child_weight=10, cla__n_estimators=30, cla__subsample=0.5; total time=   2.2s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=4, cla__min_child_weight=10, cla__n_estimators=30, cla__subsample=0.6; total time=   2.1s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=4, cla__min_child_weight=10, cla__n_estimators=30, cla__subsample=0.6; total time=   2.0s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=4, cla__min_child_weight=10, cla__n_estimators=30, cla__subsample=0.6; total time=   2.1s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=3, cla__min_child_weight=10, cla__n_estimators=200, cla__subsample=0.4; total time=  10.9s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=3, cla__min_child_weight=10, cla__n_estimators=200, cla__subsample=0.4; total time=  11.3s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=3, cla__min_child_weight=10, cla__n_estimators=200, cla__subsample=0.4; total time=  11.8s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=3, cla__min_child_weight=10, cla__n_estimators=200, cla__subsample=0.5; total time=  10.7s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=3, cla__min_child_weight=10, cla__n_estimators=200, cla__subsample=0.6; total time=  10.6s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=3, cla__min_child_weight=10, cla__n_estimators=200, cla__subsample=0.6; total time=  10.6s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=3, cla__min_child_weight=10, cla__n_estimators=200, cla__subsample=0.5; total time=  10.9s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=4, cla__min_child_weight=10, cla__n_estimators=100, cla__subsample=0.5; total time=   6.3s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=3, cla__min_child_weight=10, cla__n_estimators=200, cla__subsample=0.5; total time=  11.3s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=4, cla__min_child_weight=10, cla__n_estimators=100, cla__subsample=0.4; total time=   6.7s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=4, cla__min_child_weight=10, cla__n_estimators=100, cla__subsample=0.4; total time=   6.8s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=4, cla__min_child_weight=10, cla__n_estimators=100, cla__subsample=0.5; total time=   6.8s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=3, cla__min_child_weight=10, cla__n_estimators=200, cla__subsample=0.6; total time=  11.4s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=4, cla__min_child_weight=10, cla__n_estimators=100, cla__subsample=0.4; total time=   7.5s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=4, cla__min_child_weight=10, cla__n_estimators=100, cla__subsample=0.6; total time=   6.2s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=5, cla__min_child_weight=10, cla__n_estimators=10, cla__subsample=0.4; total time=   0.9s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=4, cla__min_child_weight=10, cla__n_estimators=100, cla__subsample=0.5; total time=   6.4s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=5, cla__min_child_weight=10, cla__n_estimators=10, cla__subsample=0.4; total time=   1.1s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=5, cla__min_child_weight=10, cla__n_estimators=10, cla__subsample=0.4; total time=   1.0s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=5, cla__min_child_weight=10, cla__n_estimators=10, cla__subsample=0.5; total time=   0.9s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=5, cla__min_child_weight=10, cla__n_estimators=10, cla__subsample=0.5; total time=   1.0s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=5, cla__min_child_weight=10, cla__n_estimators=10, cla__subsample=0.5; total time=   1.1s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=5, cla__min_child_weight=10, cla__n_estimators=10, cla__subsample=0.6; total time=   1.0s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=5, cla__min_child_weight=10, cla__n_estimators=10, cla__subsample=0.6; total time=   1.1s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=4, cla__min_child_weight=10, cla__n_estimators=100, cla__subsample=0.6; total time=   6.2s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=5, cla__min_child_weight=10, cla__n_estimators=10, cla__subsample=0.6; total time=   0.9s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=4, cla__min_child_weight=10, cla__n_estimators=100, cla__subsample=0.6; total time=   6.6s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=5, cla__min_child_weight=10, cla__n_estimators=30, cla__subsample=0.4; total time=   2.6s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=5, cla__min_child_weight=10, cla__n_estimators=30, cla__subsample=0.4; total time=   2.7s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=5, cla__min_child_weight=10, cla__n_estimators=30, cla__subsample=0.4; total time=   2.8s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=5, cla__min_child_weight=10, cla__n_estimators=30, cla__subsample=0.5; total time=   2.4s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=5, cla__min_child_weight=10, cla__n_estimators=30, cla__subsample=0.5; total time=   2.5s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=5, cla__min_child_weight=10, cla__n_estimators=30, cla__subsample=0.5; total time=   2.6s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=5, cla__min_child_weight=10, cla__n_estimators=30, cla__subsample=0.6; total time=   2.4s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=5, cla__min_child_weight=10, cla__n_estimators=30, cla__subsample=0.6; total time=   2.6s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=5, cla__min_child_weight=10, cla__n_estimators=30, cla__subsample=0.6; total time=   2.5s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=4, cla__min_child_weight=10, cla__n_estimators=200, cla__subsample=0.4; total time=  12.8s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=4, cla__min_child_weight=10, cla__n_estimators=200, cla__subsample=0.4; total time=  12.4s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=4, cla__min_child_weight=10, cla__n_estimators=200, cla__subsample=0.5; total time=  12.9s
# [CV] END cla__colsample_bytree=0.3, cla__gamma=0, cla__learning_rate=0.05, cla__max_depth=4, cla__min_child_weight=10, cla__n_estimators=200, cla__subsample=0.5; total time=  13.2s
# ...
# [CV] END cla__colsample_bytree=0.7, cla__gamma=0.5, cla__learning_rate=0.3, cla__max_depth=2, cla__min_child_weight=10, cla__n_estimators=200, cla__subsample=0.6; total time=   8.8s
# [CV] END cla__colsample_bytree=0.7, cla__gamma=0.5, cla__learning_rate=0.3, cla__max_depth=3, cla__min_child_weight=10, cla__n_estimators=100, cla__subsample=0.4; total time=   5.7s
# [CV] END cla__colsample_bytree=0.7, cla__gamma=0.5, cla__learning_rate=0.3, cla__max_depth=3, cla__min_child_weight=10, cla__n_estimators=100, cla__subsample=0.5; total time=   5.2s
# [CV] END cla__colsample_bytree=0.7, cla__gamma=0.5, cla__learning_rate=0.3, cla__max_depth=3, cla__min_child_weight=10, cla__n_estimators=100, cla__subsample=0.6; total time=   4.9s
# [CV] END cla__colsample_bytree=0.7, cla__gamma=0.5, cla__learning_rate=0.3, cla__max_depth=4, cla__min_child_weight=10, cla__n_estimators=10, cla__subsample=0.4; total time=   0.9s
# [CV] END cla__colsample_bytree=0.7, cla__gamma=0.5, cla__learning_rate=0.3, cla__max_depth=4, cla__min_child_weight=10, cla__n_estimators=10, cla__subsample=0.4; total time=   0.9s
# [CV] END cla__colsample_bytree=0.7, cla__gamma=0.5, cla__learning_rate=0.3, cla__max_depth=4, cla__min_child_weight=10, cla__n_estimators=10, cla__subsample=0.4; total time=   0.9s
# [CV] END cla__colsample_bytree=0.7, cla__gamma=0.5, cla__learning_rate=0.3, cla__max_depth=3, cla__min_child_weight=10, cla__n_estimators=100, cla__subsample=0.5; total time=   5.2s
# [CV] END cla__colsample_bytree=0.7, cla__gamma=0.5, cla__learning_rate=0.3, cla__max_depth=4, cla__min_child_weight=10, cla__n_estimators=10, cla__subsample=0.5; total time=   0.9s
# [CV] END cla__colsample_bytree=0.7, cla__gamma=0.5, cla__learning_rate=0.3, cla__max_depth=3, cla__min_child_weight=10, cla__n_estimators=100, cla__subsample=0.6; total time=   5.1s
# [CV] END cla__colsample_bytree=0.7, cla__gamma=0.5, cla__learning_rate=0.3, cla__max_depth=4, cla__min_child_weight=10, cla__n_estimators=10, cla__subsample=0.5; total time=   0.9s
# [CV] END cla__colsample_bytree=0.7, cla__gamma=0.5, cla__learning_rate=0.3, cla__max_depth=4, cla__min_child_weight=10, cla__n_estimators=10, cla__subsample=0.6; total time=   0.8s
# [CV] END cla__colsample_bytree=0.7, cla__gamma=0.5, cla__learning_rate=0.3, cla__max_depth=4, cla__min_child_weight=10, cla__n_estimators=10, cla__subsample=0.5; total time=   1.0s
# [CV] END cla__colsample_bytree=0.7, cla__gamma=0.5, cla__learning_rate=0.3, cla__max_depth=4, cla__min_child_weight=10, cla__n_estimators=10, cla__subsample=0.6; total time=   0.9s
# [CV] END cla__colsample_bytree=0.7, cla__gamma=0.5, cla__learning_rate=0.3, cla__max_depth=3, cla__min_child_weight=10, cla__n_estimators=100, cla__subsample=0.6; total time=   5.2s
# [CV] END cla__colsample_bytree=0.7, cla__gamma=0.5, cla__learning_rate=0.3, cla__max_depth=4, cla__min_child_weight=10, cla__n_estimators=10, cla__subsample=0.6; total time=   0.9s
# [CV] END cla__colsample_bytree=0.7, cla__gamma=0.5, cla__learning_rate=0.3, cla__max_depth=4, cla__min_child_weight=10, cla__n_estimators=30, cla__subsample=0.4; total time=   2.2s
# [CV] END cla__colsample_bytree=0.7, cla__gamma=0.5, cla__learning_rate=0.3, cla__max_depth=4, cla__min_child_weight=10, cla__n_estimators=30, cla__subsample=0.4; total time=   2.2s
# [CV] END cla__colsample_bytree=0.7, cla__gamma=0.5, cla__learning_rate=0.3, cla__max_depth=4, cla__min_child_weight=10, cla__n_estimators=30, cla__subsample=0.5; total time=   2.1s
# [CV] END cla__colsample_bytree=0.7, cla__gamma=0.5, cla__learning_rate=0.3, cla__max_depth=4, cla__min_child_weight=10, cla__n_estimators=30, cla__subsample=0.4; total time=   2.3s
# [CV] END cla__colsample_bytree=0.7, cla__gamma=0.5, cla__learning_rate=0.3, cla__max_depth=4, cla__min_child_weight=10, cla__n_estimators=30, cla__subsample=0.5; total time=   2.3s
# [CV] END cla__colsample_bytree=0.7, cla__gamma=0.5, cla__learning_rate=0.3, cla__max_depth=4, cla__min_child_weight=10, cla__n_estimators=30, cla__subsample=0.5; total time=   2.3s
# [CV] END cla__colsample_bytree=0.7, cla__gamma=0.5, cla__learning_rate=0.3, cla__max_depth=4, cla__min_child_weight=10, cla__n_estimators=30, cla__subsample=0.6; total time=   2.2s
# [CV] END cla__colsample_bytree=0.7, cla__gamma=0.5, cla__learning_rate=0.3, cla__max_depth=4, cla__min_child_weight=10, cla__n_estimators=30, cla__subsample=0.6; total time=   2.2s
# [CV] END cla__colsample_bytree=0.7, cla__gamma=0.5, cla__learning_rate=0.3, cla__max_depth=4, cla__min_child_weight=10, cla__n_estimators=30, cla__subsample=0.6; total time=   2.4s
# [CV] END cla__colsample_bytree=0.7, cla__gamma=0.5, cla__learning_rate=0.3, cla__max_depth=3, cla__min_child_weight=10, cla__n_estimators=200, cla__subsample=0.4; total time=  10.8s
# [CV] END cla__colsample_bytree=0.7, cla__gamma=0.5, cla__learning_rate=0.3, cla__max_depth=3, cla__min_child_weight=10, cla__n_estimators=200, cla__subsample=0.4; total time=  10.6s
# [CV] END cla__colsample_bytree=0.7, cla__gamma=0.5, cla__learning_rate=0.3, cla__max_depth=3, cla__min_child_weight=10, cla__n_estimators=200, cla__subsample=0.4; total time=  10.9s
# [CV] END cla__colsample_bytree=0.7, cla__gamma=0.5, cla__learning_rate=0.3, cla__max_depth=3, cla__min_child_weight=10, cla__n_estimators=200, cla__subsample=0.5; total time=  10.1s
# [CV] END cla__colsample_bytree=0.7, cla__gamma=0.5, cla__learning_rate=0.3, cla__max_depth=3, cla__min_child_weight=10, cla__n_estimators=200, cla__subsample=0.5; total time=  10.2s
# [CV] END cla__colsample_bytree=0.7, cla__gamma=0.5, cla__learning_rate=0.3, cla__max_depth=3, cla__min_child_weight=10, cla__n_estimators=200, cla__subsample=0.5; total time=  10.6s
# [CV] END cla__colsample_bytree=0.7, cla__gamma=0.5, cla__learning_rate=0.3, cla__max_depth=4, cla__min_child_weight=10, cla__n_estimators=100, cla__subsample=0.4; total time=   6.0s
# [CV] END cla__colsample_bytree=0.7, cla__gamma=0.5, cla__learning_rate=0.3, cla__max_depth=3, cla__min_child_weight=10, cla__n_estimators=200, cla__subsample=0.6; total time=  10.4s
# [CV] END cla__colsample_bytree=0.7, cla__gamma=0.5, cla__learning_rate=0.3, cla__max_depth=3, cla__min_child_weight=10, cla__n_estimators=200, cla__subsample=0.6; total time=  10.4s
# [CV] END cla__colsample_bytree=0.7, cla__gamma=0.5, cla__learning_rate=0.3, cla__max_depth=3, cla__min_child_weight=10, cla__n_estimators=200, cla__subsample=0.6; total time=  10.5s
# [CV] END cla__colsample_bytree=0.7, cla__gamma=0.5, cla__learning_rate=0.3, cla__max_depth=4, cla__min_child_weight=10, cla__n_estimators=100, cla__subsample=0.4; total time=   6.2s
# [CV] END cla__colsample_bytree=0.7, cla__gamma=0.5, cla__learning_rate=0.3, cla__max_depth=4, cla__min_child_weight=10, cla__n_estimators=100, cla__subsample=0.5; total time=   5.9s
# [CV] END cla__colsample_bytree=0.7, cla__gamma=0.5, cla__learning_rate=0.3, cla__max_depth=4, cla__min_child_weight=10, cla__n_estimators=100, cla__subsample=0.4; total time=   6.4s
# [CV] END cla__colsample_bytree=0.7, cla__gamma=0.5, cla__learning_rate=0.3, cla__max_depth=4, cla__min_child_weight=10, cla__n_estimators=100, cla__subsample=0.5; total time=   5.8s
# [CV] END cla__colsample_bytree=0.7, cla__gamma=0.5, cla__learning_rate=0.3, cla__max_depth=5, cla__min_child_weight=10, cla__n_estimators=10, cla__subsample=0.4; total time=   1.0s
# [CV] END cla__colsample_bytree=0.7, cla__gamma=0.5, cla__learning_rate=0.3, cla__max_depth=5, cla__min_child_weight=10, cla__n_estimators=10, cla__subsample=0.4; total time=   1.0s
# [CV] END cla__colsample_bytree=0.7, cla__gamma=0.5, cla__learning_rate=0.3, cla__max_depth=5, cla__min_child_weight=10, cla__n_estimators=10, cla__subsample=0.4; total time=   1.0s
# [CV] END cla__colsample_bytree=0.7, cla__gamma=0.5, cla__learning_rate=0.3, cla__max_depth=5, cla__min_child_weight=10, cla__n_estimators=10, cla__subsample=0.5; total time=   1.0s
# [CV] END cla__colsample_bytree=0.7, cla__gamma=0.5, cla__learning_rate=0.3, cla__max_depth=5, cla__min_child_weight=10, cla__n_estimators=10, cla__subsample=0.5; total time=   1.0s
# [CV] END cla__colsample_bytree=0.7, cla__gamma=0.5, cla__learning_rate=0.3, cla__max_depth=5, cla__min_child_weight=10, cla__n_estimators=10, cla__subsample=0.5; total time=   1.0s
# [CV] END cla__colsample_bytree=0.7, cla__gamma=0.5, cla__learning_rate=0.3, cla__max_depth=4, cla__min_child_weight=10, cla__n_estimators=100, cla__subsample=0.6; total time=   6.4s
# [CV] END cla__colsample_bytree=0.7, cla__gamma=0.5, cla__learning_rate=0.3, cla__max_depth=4, cla__min_child_weight=10, cla__n_estimators=100, cla__subsample=0.5; total time=   6.9s
# [CV] END cla__colsample_bytree=0.7, cla__gamma=0.5, cla__learning_rate=0.3, cla__max_depth=5, cla__min_child_weight=10, cla__n_estimators=10, cla__subsample=0.6; total time=   1.0s
# [CV] END cla__colsample_bytree=0.7, cla__gamma=0.5, cla__learning_rate=0.3, cla__max_depth=5, cla__min_child_weight=10, cla__n_estimators=10, cla__subsample=0.6; total time=   0.9s
# [CV] END cla__colsample_bytree=0.7, cla__gamma=0.5, cla__learning_rate=0.3, cla__max_depth=5, cla__min_child_weight=10, cla__n_estimators=10, cla__subsample=0.6; total time=   1.1s
# [CV] END cla__colsample_bytree=0.7, cla__gamma=0.5, cla__learning_rate=0.3, cla__max_depth=4, cla__min_child_weight=10, cla__n_estimators=100, cla__subsample=0.6; total time=   5.8s
# [CV] END cla__colsample_bytree=0.7, cla__gamma=0.5, cla__learning_rate=0.3, cla__max_depth=4, cla__min_child_weight=10, cla__n_estimators=100, cla__subsample=0.6; total time=   6.2s
# [CV] END cla__colsample_bytree=0.7, cla__gamma=0.5, cla__learning_rate=0.3, cla__max_depth=5, cla__min_child_weight=10, cla__n_estimators=30, cla__subsample=0.4; total time=   2.5s
# [CV] END cla__colsample_bytree=0.7, cla__gamma=0.5, cla__learning_rate=0.3, cla__max_depth=5, cla__min_child_weight=10, cla__n_estimators=30, cla__subsample=0.4; total time=   2.4s
# [CV] END cla__colsample_bytree=0.7, cla__gamma=0.5, cla__learning_rate=0.3, cla__max_depth=5, cla__min_child_weight=10, cla__n_estimators=30, cla__subsample=0.5; total time=   2.3s
# [CV] END cla__colsample_bytree=0.7, cla__gamma=0.5, cla__learning_rate=0.3, cla__max_depth=5, cla__min_child_weight=10, cla__n_estimators=30, cla__subsample=0.4; total time=   2.5s
# [CV] END cla__colsample_bytree=0.7, cla__gamma=0.5, cla__learning_rate=0.3, cla__max_depth=5, cla__min_child_weight=10, cla__n_estimators=30, cla__subsample=0.5; total time=   2.5s
# [CV] END cla__colsample_bytree=0.7, cla__gamma=0.5, cla__learning_rate=0.3, cla__max_depth=5, cla__min_child_weight=10, cla__n_estimators=30, cla__subsample=0.5; total time=   2.2s
# [CV] END cla__colsample_bytree=0.7, cla__gamma=0.5, cla__learning_rate=0.3, cla__max_depth=5, cla__min_child_weight=10, cla__n_estimators=30, cla__subsample=0.6; total time=   2.4s
# [CV] END cla__colsample_bytree=0.7, cla__gamma=0.5, cla__learning_rate=0.3, cla__max_depth=5, cla__min_child_weight=10, cla__n_estimators=30, cla__subsample=0.6; total time=   2.7s
# [CV] END cla__colsample_bytree=0.7, cla__gamma=0.5, cla__learning_rate=0.3, cla__max_depth=5, cla__min_child_weight=10, cla__n_estimators=30, cla__subsample=0.6; total time=   2.7s
# [CV] END cla__colsample_bytree=0.7, cla__gamma=0.5, cla__learning_rate=0.3, cla__max_depth=4, cla__min_child_weight=10, cla__n_estimators=200, cla__subsample=0.4; total time=  11.7s
# [CV] END cla__colsample_bytree=0.7, cla__gamma=0.5, cla__learning_rate=0.3, cla__max_depth=4, cla__min_child_weight=10, cla__n_estimators=200, cla__subsample=0.4; total time=  12.6s
# [CV] END cla__colsample_bytree=0.7, cla__gamma=0.5, cla__learning_rate=0.3, cla__max_depth=4, cla__min_child_weight=10, cla__n_estimators=200, cla__subsample=0.4; total time=  12.1s
# [CV] END cla__colsample_bytree=0.7, cla__gamma=0.5, cla__learning_rate=0.3, cla__max_depth=4, cla__min_child_weight=10, cla__n_estimators=200, cla__subsample=0.5; total time=  12.0s
# [CV] END cla__colsample_bytree=0.7, cla__gamma=0.5, cla__learning_rate=0.3, cla__max_depth=5, cla__min_child_weight=10, cla__n_estimators=100, cla__subsample=0.4; total time=   6.4s
# [CV] END cla__colsample_bytree=0.7, cla__gamma=0.5, cla__learning_rate=0.3, cla__max_depth=4, cla__min_child_weight=10, cla__n_estimators=200, cla__subsample=0.6; total time=  12.2s
# [CV] END cla__colsample_bytree=0.7, cla__gamma=0.5, cla__learning_rate=0.3, cla__max_depth=4, cla__min_child_weight=10, cla__n_estimators=200, cla__subsample=0.5; total time=  12.3s
# [CV] END cla__colsample_bytree=0.7, cla__gamma=0.5, cla__learning_rate=0.3, cla__max_depth=4, cla__min_child_weight=10, cla__n_estimators=200, cla__subsample=0.6; total time=  12.3s
# [CV] END cla__colsample_bytree=0.7, cla__gamma=0.5, cla__learning_rate=0.3, cla__max_depth=4, cla__min_child_weight=10, cla__n_estimators=200, cla__subsample=0.6; total time=  12.4s
# [CV] END cla__colsample_bytree=0.7, cla__gamma=0.5, cla__learning_rate=0.3, cla__max_depth=5, cla__min_child_weight=10, cla__n_estimators=100, cla__subsample=0.4; total time=   6.9s
# [CV] END cla__colsample_bytree=0.7, cla__gamma=0.5, cla__learning_rate=0.3, cla__max_depth=4, cla__min_child_weight=10, cla__n_estimators=200, cla__subsample=0.5; total time=  12.9s
# [CV] END cla__colsample_bytree=0.7, cla__gamma=0.5, cla__learning_rate=0.3, cla__max_depth=5, cla__min_child_weight=10, cla__n_estimators=100, cla__subsample=0.4; total time=   6.9s
# [CV] END cla__colsample_bytree=0.7, cla__gamma=0.5, cla__learning_rate=0.3, cla__max_depth=5, cla__min_child_weight=10, cla__n_estimators=100, cla__subsample=0.5; total time=   6.8s
# [CV] END cla__colsample_bytree=0.7, cla__gamma=0.5, cla__learning_rate=0.3, cla__max_depth=5, cla__min_child_weight=10, cla__n_estimators=100, cla__subsample=0.5; total time=   6.4s
# [CV] END cla__colsample_bytree=0.7, cla__gamma=0.5, cla__learning_rate=0.3, cla__max_depth=5, cla__min_child_weight=10, cla__n_estimators=100, cla__subsample=0.5; total time=   6.3s
# [CV] END cla__colsample_bytree=0.7, cla__gamma=0.5, cla__learning_rate=0.3, cla__max_depth=5, cla__min_child_weight=10, cla__n_estimators=100, cla__subsample=0.6; total time=   6.4s
# [CV] END cla__colsample_bytree=0.7, cla__gamma=0.5, cla__learning_rate=0.3, cla__max_depth=5, cla__min_child_weight=10, cla__n_estimators=100, cla__subsample=0.6; total time=   4.6s
# [CV] END cla__colsample_bytree=0.7, cla__gamma=0.5, cla__learning_rate=0.3, cla__max_depth=5, cla__min_child_weight=10, cla__n_estimators=100, cla__subsample=0.6; total time=   5.7s
# [CV] END cla__colsample_bytree=0.7, cla__gamma=0.5, cla__learning_rate=0.3, cla__max_depth=5, cla__min_child_weight=10, cla__n_estimators=200, cla__subsample=0.4; total time=   6.9s
# [CV] END cla__colsample_bytree=0.7, cla__gamma=0.5, cla__learning_rate=0.3, cla__max_depth=5, cla__min_child_weight=10, cla__n_estimators=200, cla__subsample=0.5; total time=   6.9s
# [CV] END cla__colsample_bytree=0.7, cla__gamma=0.5, cla__learning_rate=0.3, cla__max_depth=5, cla__min_child_weight=10, cla__n_estimators=200, cla__subsample=0.4; total time=   7.3s
# [CV] END cla__colsample_bytree=0.7, cla__gamma=0.5, cla__learning_rate=0.3, cla__max_depth=5, cla__min_child_weight=10, cla__n_estimators=200, cla__subsample=0.6; total time=   7.2s
# [CV] END cla__colsample_bytree=0.7, cla__gamma=0.5, cla__learning_rate=0.3, cla__max_depth=5, cla__min_child_weight=10, cla__n_estimators=200, cla__subsample=0.4; total time=   8.2s
# [CV] END cla__colsample_bytree=0.7, cla__gamma=0.5, cla__learning_rate=0.3, cla__max_depth=5, cla__min_child_weight=10, cla__n_estimators=200, cla__subsample=0.6; total time=   7.3s
# [CV] END cla__colsample_bytree=0.7, cla__gamma=0.5, cla__learning_rate=0.3, cla__max_depth=5, cla__min_child_weight=10, cla__n_estimators=200, cla__subsample=0.5; total time=   7.8s
# [CV] END cla__colsample_bytree=0.7, cla__gamma=0.5, cla__learning_rate=0.3, cla__max_depth=5, cla__min_child_weight=10, cla__n_estimators=200, cla__subsample=0.5; total time=   8.2s
# [CV] END cla__colsample_bytree=0.7, cla__gamma=0.5, cla__learning_rate=0.3, cla__max_depth=5, cla__min_child_weight=10, cla__n_estimators=200, cla__subsample=0.6; total time=   8.1s

# %%
print('Mejor modelo:\n')
print(best_model)
print(best_params)
print(best_score)
print(type(best_params))
print(best_params[0]['cla__colsample_bytree'])
params = best_params[0]
# Out:
# Mejor modelo:
#
# [Pipeline(steps=[('std', StandardScaler()),
#                 ('cla',
#                  XGBClassifier(base_score=None, booster=None, callbacks=None,
#                                colsample_bylevel=None, colsample_bynode=None,
#                                colsample_bytree=0.7, device=None,
#                                early_stopping_rounds=None,
#                                enable_categorical=False, eval_metric=None,
#                                feature_types=None, gamma=0, grow_policy=None,
#                                importance_type=None,
#                                interaction_constraints=None, learning_rate=0.3,
#                                max_bin=None, max_cat_threshold=None,
#                                max_cat_to_onehot=None, max_delta_step=None,
#                                max_depth=5, max_leaves=None,
#                                min_child_weight=10, missing=nan,
#                                monotone_constraints=None, multi_strategy=None,
#                                n_estimators=200, n_jobs=None,
#                                num_parallel_tree=None,
#                                objective='multi:softprob', ...))])]
# [{'cla__colsample_bytree': 0.7, 'cla__gamma': 0, 'cla__learning_rate': 0.3, 'cla__max_depth': 5, 'cla__min_child_weight': 10, 'cla__n_estimators': 200, 'cla__subsample': 0.6}]
# [0.8046477167463121]
# <class 'list'>
# 0.7

# %%
# #max_depth
# maxd = 2
# #n_estimators
# ne = 200
# #subsample
# sb = 0.4
# #gamma 
# g = 0

model = xgb.XGBClassifier(objective="multi:softprob", random_state=42, eval_metric="auc",
                          colsample_bytree=params['cla__colsample_bytree'], 
                          gamma=params['cla__gamma'], learning_rate=params['cla__learning_rate'], 
                          max_depth=params['cla__max_depth'], min_child_weight= params['cla__min_child_weight'], 
                          n_estimators=params['cla__n_estimators'], subsample=params['cla__subsample'])

#train the model
sca = StandardScaler()
X2 = sca.fit_transform(X2)
# model = KNeighborsClassifier(n_neighbors=nneighb)
# model = xgb.XGBClassifier(objective="multi:softprob", random_state=42, eval_metric="auc", 
# max_depth=maxd, n_estimators=ne, subsample=sb, gamma=g)
model.fit(X2,y2)

#test the model
Xtest = sca.transform(Xtest)
ypred = model.predict(Xtest)
acc = accuracy_score(ytest, ypred)
rec = recall_score(ytest, ypred, average='weighted')
f1 = f1_score(ytest, ypred, average='weighted')

# print("Gamma: %s" % g)

# print("n_estimators: %s" % ne)

# print("max_depth: %s" % maxd)

# print("subsample: %s" % sb)


#show and results
print("  Accuracy: %s" % acc)
print("  F1-Score: %s" % f1)
print("  Recall: %s" % rec)
# Out:
#   Accuracy: 0.4690114260058459
#   F1-Score: 0.518858671433145
#   Recall: 0.4690114260058459
